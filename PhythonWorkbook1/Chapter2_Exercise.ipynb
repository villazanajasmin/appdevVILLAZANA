# %% [markdown]
# Exercise 1

# %%
#Enter your name: Chuck
#Hello Chuck
# Prompting the user for their name
name = input("Enter your name: ")

# Displaying the welcome message with the user's name
print("Hello", name)

# %% [markdown]
# Exercise 2

# %%
#Enter Hours: 35
#Enter Rate: 2.75
#Pay: 96.25
# Prompting the user for hours worked and rate per hour
hours_worked = float(input("Enter the number of hours worked: "))
rate_per_hour = float(input("Enter the rate per hour: "))

# Calculating gross pay
gross_pay = hours_worked * rate_per_hour

# Displaying the gross pay
print("Gross pay: $", gross_pay)

# %% [markdown]
# Exercise 3

# %%
#Enter Hours: 35
#Enter Rate: 2.75
#Pay: 96.25
# Prompting the user for hours worked and rate per hour
hours_worked = float(input("Enter the number of hours worked: "))
rate_per_hour = float(input("Enter the rate per hour: "))

# Calculating gross pay
gross_pay = hours_worked * rate_per_hour

# Displaying the gross pay
print("Gross pay: $", gross_pay)

# %%
width//2
width/2.0
height/3
1 + 2 * 5
# Prompting the user for hours worked and rate per hour
hours_worked = float(input("Enter the number of hours worked: "))
rate_per_hour = float(input("Enter the rate per hour: "))

# Calculating gross pay
gross_pay = hours_worked * rate_per_hour

# Displaying the gross pay
print("Gross pay: $", gross_pay)

# Calculation of expressions
width = 17
height = 12.0

print("width//2 =", width//2)
print("width/2.0 =", width/2.0)
print("height/3 =", height/3)
print("1 + 2 * 5 =", 1 + 2 * 5)
